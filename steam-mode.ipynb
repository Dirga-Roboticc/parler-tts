# %%
# !pip install git+https://github.com/huggingface/parler-tts.git
# !pip install flash-attn
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

import torch
from parler_tts import ParlerTTSForConditionalGeneration, ParlerTTSStreamer
from transformers import AutoTokenizer
from threading import Thread
import sounddevice as sd
import queue

if torch.cuda.is_available():
    print(f"CUDA is available. Device count: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"Device {i}: {torch.cuda.get_device_name(i)}")
    print(f"Current device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("CUDA is not available. Using CPU.")

torch_device = "cuda:0" # Use "mps" for Mac 
torch_dtype = torch.bfloat16
model_name = "parler-tts/parler-tts-mini-v1"

# need to set padding max length
max_length = 50

# load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name) 
model = ParlerTTSForConditionalGeneration.from_pretrained(
    model_name,
).to(torch_device, dtype=torch_dtype)

sampling_rate = model.audio_encoder.config.sampling_rate
frame_rate = model.audio_encoder.config.frame_rate
# Out:
# Collecting git+https://github.com/huggingface/parler-tts.git
#   Cloning https://github.com/huggingface/parler-tts.git to /tmp/pip-req-build-4kvtkpys
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /tmp/pip-req-build-4kvtkpys
#   Resolved https://github.com/huggingface/parler-tts.git to commit 5d0aca9753ab74ded179732f5bd797f7a8c6f8ee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers<=4.43.3,>=4.43.0 in ./.conda/lib/python3.11/site-packages (from parler_tts==0.2) (4.43.3)
# Requirement already satisfied: torch in ./.conda/lib/python3.11/site-packages (from parler_tts==0.2) (2.4.1)
# Requirement already satisfied: sentencepiece in ./.conda/lib/python3.11/site-packages (from parler_tts==0.2) (0.2.0)
# Requirement already satisfied: descript-audio-codec in ./.conda/lib/python3.11/site-packages (from parler_tts==0.2) (1.0.0)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (0.25.2)
# Requirement already satisfied: numpy>=1.17 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (2024.9.11)
# Requirement already satisfied: requests in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in ./.conda/lib/python3.11/site-packages (from transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (4.66.5)
# Requirement already satisfied: argbind>=0.3.7 in ./.conda/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2) (0.3.9)
# Requirement already satisfied: descript-audiotools>=0.7.2 in ./.conda/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2) (0.7.2)
# Requirement already satisfied: einops in ./.conda/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2) (0.8.0)
# Requirement already satisfied: torchaudio in ./.conda/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2) (2.4.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (4.11.0)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (1.13.3)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (3.4.1)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (3.1.4)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./.conda/lib/python3.11/site-packages (from torch->parler_tts==0.2) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->parler_tts==0.2) (12.6.77)
# Requirement already satisfied: docstring-parser in ./.conda/lib/python3.11/site-packages (from argbind>=0.3.7->descript-audio-codec->parler_tts==0.2) (0.16)
# Requirement already satisfied: soundfile in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.12.1)
# Requirement already satisfied: pyloudnorm in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.1.1)
# Requirement already satisfied: importlib-resources in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (6.4.5)
# Requirement already satisfied: scipy in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.14.1)
# Requirement already satisfied: julius in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.7)
# Requirement already satisfied: ffmpy in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.4.0)
# Requirement already satisfied: ipython in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (8.27.0)
# Requirement already satisfied: rich in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (13.9.2)
# Requirement already satisfied: matplotlib in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.9.2)
# Requirement already satisfied: librosa in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.10.2.post1)
# Requirement already satisfied: pystoi in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.4.1)
# Requirement already satisfied: torch-stoi in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.3)
# Requirement already satisfied: flatten-dict in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.4.2)
# Requirement already satisfied: markdown2 in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.5.1)
# Requirement already satisfied: randomname in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.19.6)
# Requirement already satisfied: tensorboard in ./.conda/lib/python3.11/site-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.11/site-packages (from jinja2->torch->parler_tts==0.2) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.11/site-packages (from requests->transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.11/site-packages (from requests->transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.11/site-packages (from requests->transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.11/site-packages (from requests->transformers<=4.43.3,>=4.43.0->parler_tts==0.2) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/lib/python3.11/site-packages (from sympy->torch->parler_tts==0.2) (1.3.0)
# Requirement already satisfied: six<2.0,>=1.12 in ./.conda/lib/python3.11/site-packages (from flatten-dict->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.16.0)
# Requirement already satisfied: decorator in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.15.1)
# Requirement already satisfied: stack-data in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in ./.conda/lib/python3.11/site-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (4.8.0)
# Requirement already satisfied: audioread>=2.1.9 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.4.2)
# Requirement already satisfied: numba>=0.51.0 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in ./.conda/lib/python3.11/site-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in ./.conda/lib/python3.11/site-packages (from soundfile->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.4.7)
# Requirement already satisfied: pillow>=8 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.11/site-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.9.0.post0)
# Requirement already satisfied: future>=0.16.0 in ./.conda/lib/python3.11/site-packages (from pyloudnorm->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.0.0)
# Requirement already satisfied: fire in ./.conda/lib/python3.11/site-packages (from randomname->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/lib/python3.11/site-packages (from rich->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (1.66.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.conda/lib/python3.11/site-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.0.4)
# Requirement already satisfied: pycparser in ./.conda/lib/python3.11/site-packages (from cffi>=1.0->soundfile->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.conda/lib/python3.11/site-packages (from jedi>=0.16->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.conda/lib/python3.11/site-packages (from numba>=0.51.0->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.conda/lib/python3.11/site-packages (from pexpect>4.3->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./.conda/lib/python3.11/site-packages (from pooch>=1.1->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.10.0)
# Requirement already satisfied: wcwidth in ./.conda/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (3.5.0)
# Requirement already satisfied: termcolor in ./.conda/lib/python3.11/site-packages (from fire->randomname->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.5.0)
# Requirement already satisfied: executing in ./.conda/lib/python3.11/site-packages (from stack-data->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.8.3)
# Requirement already satisfied: asttokens in ./.conda/lib/python3.11/site-packages (from stack-data->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (2.0.5)
# Requirement already satisfied: pure-eval in ./.conda/lib/python3.11/site-packages (from stack-data->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.2) (0.2.2)
# Requirement already satisfied: flash-attn in ./.conda/lib/python3.11/site-packages (2.6.3)
# Requirement already satisfied: torch in ./.conda/lib/python3.11/site-packages (from flash-attn) (2.4.1)
# Requirement already satisfied: einops in ./.conda/lib/python3.11/site-packages (from flash-attn) (0.8.0)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (4.11.0)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (1.13.3)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (3.4.1)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (3.1.4)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./.conda/lib/python3.11/site-packages (from torch->flash-attn) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.11/site-packages (from jinja2->torch->flash-attn) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/lib/python3.11/site-packages (from sympy->torch->flash-attn) (1.3.0)
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in ./.conda/lib/python3.11/site-packages (2.4.1)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu124/torchvision-0.19.1%2Bcu124-cp311-cp311-linux_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 189.0 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio in ./.conda/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.11/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.conda/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.conda/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./.conda/lib/python3.11/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.77)
# Requirement already satisfied: numpy in ./.conda/lib/python3.11/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/lib/python3.11/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.19.1+cu124
# CUDA is available. Device count: 1
# Device 0: NVIDIA L4
# Current device: 0 - NVIDIA L4
# /home/user/Documents/tts/parler-tts/.conda/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
# Queue to buffer audio chunks
audio_queue = queue.Queue()

def audio_player():
    """Thread to play audio from the queue"""
    while True:
        audio_chunk = audio_queue.get()
        if audio_chunk is None:
            break
        sd.play(audio_chunk, samplerate=sampling_rate)
        sd.wait()  # Wait until the sound has finished playing

def generate(text, description, play_steps_in_s=0.5):
    play_steps = int(frame_rate * play_steps_in_s)
    streamer = ParlerTTSStreamer(model, device=torch_device, play_steps=play_steps)
    
    # Tokenization
    inputs = tokenizer(description, return_tensors="pt").to(torch_device)
    prompt = tokenizer(text, return_tensors="pt").to(torch_device)
    
    # Generation kwargs
    generation_kwargs = dict(
        input_ids=inputs.input_ids,
        prompt_input_ids=prompt.input_ids,
        attention_mask=inputs.attention_mask,
        prompt_attention_mask=prompt.attention_mask,
        streamer=streamer,
        do_sample=True,
        temperature=1.0,
        min_new_tokens=10,
    )
    
    # Initialize Thread
    thread = Thread(target=model.generate, kwargs=generation_kwargs)
    thread.start()
    
    # Iterate over chunks of audio and put them in the queue
    for new_audio in streamer:
        if new_audio.shape[0] == 0:
            break
        print(f"Sample of length: {round(new_audio.shape[0] / sampling_rate, 4)} seconds")
        audio_queue.put(new_audio)  # Add audio chunk to queue

# Now you can do
text = "This is a test of the streamer class"
description = "Jon's talking really fast."
chunk_size_in_s = 0.5

# Start the audio player thread
player_thread = Thread(target=audio_player, daemon=True)
player_thread.start()

# Generate audio and fill the queue
generate(text, description, chunk_size_in_s)

# Wait until all audio chunks are played
audio_queue.put(None)  # Signal end of audio to the player thread
player_thread.join()
# Out:
# `prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# Sample of length: 0.329 seconds
# (14507,)
# Sample of length: 0.4992 seconds
# (22016,)
# Sample of length: 0.4992 seconds
# (22016,)
# Sample of length: 0.4992 seconds
# (22016,)
# Sample of length: 0.0658 seconds
# (2901,)
